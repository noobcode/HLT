# %%
import numpy as np
import pandas as pd
from nltk import word_tokenize

from paths import *

from sklearn.svm import SVC, LinearSVC
from sklearn.grid_search import GridSearchCV

from feature_transformer import *
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# ### Loading the preprocessed embeddings

# %%
X_train = np.load('../XY/STEM_20/X_train.npy')
Y_train = np.load('../XY/STEM_20/Y_train.npy')
X_test = np.load('../XY/STEM_20/X_test2.npy')
Y_test = np.load('../XY/STEM_20/Y_test2.npy')

print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (148031, 20) (148031,)
# (29841, 20) (29841,)

# %% [markdown]
# ### Loading the sentences

# %%
# TRAIN SET
sentences_df_train = pd.read_csv(SENTENCE_PATH_train)
entities_df_train = pd.read_csv(ENTITY_PATH_train)
pairs_df_train = pd.read_csv(PAIR_PATH_train)

#TEST2 SET
sentences_df_test = pd.read_csv(SENTENCE_PATH_test2)
entities_df_test = pd.read_csv(ENTITY_PATH_test2)
pairs_df_test = pd.read_csv(PAIR_PATH_test2)

pairs_df_train['type'].fillna('null', inplace=True)

# %%
Y_tr = np.empty((pairs_df_train.shape[0],))
Y_tr_type = np.zeros([pairs_df_train.shape[0], 1])

for index, row in pairs_df_train.iterrows():
    t = row['type']
    if t == 'mechanism':
        Y_tr_type[index, 0] = 1
    elif t == 'int':
        Y_tr_type[index, 0] = 2
    elif t == 'advise':
        Y_tr_type[index, 0] = 3
    elif t == 'effect':
        Y_tr_type[index, 0] = 4
    else:
        Y_tr_type[index, 0] = 0
        
    Y_tr[index] = 1 if row['ddi'] is True else 0
    
np.save(os.path.join(ROOT_DIR, 'XY', 'Y', 'Task2', 'Y_train.npy'), Y_tr)
np.save(os.path.join(ROOT_DIR, 'XY', 'Y', 'Task2', 'Y_train_type.npy'), Y_tr_type)

# %%
Y_tr = np.load(os.path.join(ROOT_DIR, 'XY', 'Y', 'Task2', 'Y_train.npy'))
Y_tr_type = np.load(os.path.join(ROOT_DIR, 'XY', 'Y', 'Task2', 'Y_train_type.npy'))

Y_tr = np.round(Y_tr)

# %%
print("entities dataframe")
entities_df_train.head()
# Out:
# entities dataframe
#                   entityID        name position   type
# 0  DDI-DrugBank.d157.s0.e0  cimetidine    34-43   drug
# 1  DDI-DrugBank.d157.s0.e1    warfarin    49-56   drug
# 2  DDI-DrugBank.d157.s0.e2      Femara   97-102  brand
# 3  DDI-DrugBank.d157.s1.e0      Femara    48-53  brand
# 4  DDI-DrugBank.d157.s1.e1   tamoxifen    59-67   drug

# %%
print("sentences dataframe")
sentences_df_train.head()
# Out:
# sentences dataframe
#              sentenceID                                       sentenceText
# 0  DDI-DrugBank.d157.s0  Clinical interaction studies with cimetidine a...
# 1  DDI-DrugBank.d157.s1  (See CLINICAL PHARMACOLOGY) Coadministration o...
# 2  DDI-DrugBank.d157.s2  There is no clinical experience to date on the...
# 3  DDI-DrugBank.d157.s3   Drug/Laboratory Test-Interactions None observed.
# 4  DDI-DrugBank.d110.s0  The administration of local anesthetic solutio...

# %%
print("pairs dataframe")
pairs_df_train.head(100)
# Out:
# pairs dataframe
#     index    ddi                 entityID1                 entityID2  \
# 0       0  False   DDI-DrugBank.d157.s0.e0   DDI-DrugBank.d157.s0.e1
# 1       1  False   DDI-DrugBank.d157.s0.e0   DDI-DrugBank.d157.s0.e2
# 2       2  False   DDI-DrugBank.d157.s0.e1   DDI-DrugBank.d157.s0.e2
# 3       3   True   DDI-DrugBank.d157.s1.e0   DDI-DrugBank.d157.s1.e1
# 4       4  False   DDI-DrugBank.d157.s1.e0   DDI-DrugBank.d157.s1.e2
# 5       5  False   DDI-DrugBank.d157.s1.e1   DDI-DrugBank.d157.s1.e2
# 6       6  False   DDI-DrugBank.d110.s0.e0   DDI-DrugBank.d110.s0.e1
# 7       7  False   DDI-DrugBank.d110.s0.e0   DDI-DrugBank.d110.s0.e2
# 8       8  False   DDI-DrugBank.d110.s0.e0   DDI-DrugBank.d110.s0.e3
# 9       9   True   DDI-DrugBank.d110.s0.e0   DDI-DrugBank.d110.s0.e4
# 10     10   True   DDI-DrugBank.d110.s0.e0   DDI-DrugBank.d110.s0.e5
# 11     11  False   DDI-DrugBank.d110.s0.e1   DDI-DrugBank.d110.s0.e2
# 12     12   True   DDI-DrugBank.d110.s0.e1   DDI-DrugBank.d110.s0.e3
# 13     13   True   DDI-DrugBank.d110.s0.e1   DDI-DrugBank.d110.s0.e4
# 14     14   True   DDI-DrugBank.d110.s0.e1   DDI-DrugBank.d110.s0.e5
# 15     15   True   DDI-DrugBank.d110.s0.e2   DDI-DrugBank.d110.s0.e3
# 16     16   True   DDI-DrugBank.d110.s0.e2   DDI-DrugBank.d110.s0.e4
# 17     17   True   DDI-DrugBank.d110.s0.e2   DDI-DrugBank.d110.s0.e5
# 18     18  False   DDI-DrugBank.d110.s0.e3   DDI-DrugBank.d110.s0.e4
# 19     19  False   DDI-DrugBank.d110.s0.e3   DDI-DrugBank.d110.s0.e5
# 20     20  False   DDI-DrugBank.d110.s0.e4   DDI-DrugBank.d110.s0.e5
# 21     21   True   DDI-DrugBank.d110.s3.e0   DDI-DrugBank.d110.s3.e1
# 22     22   True   DDI-DrugBank.d110.s5.e0   DDI-DrugBank.d110.s5.e1
# 23     23   True     DDI-DrugBank.d7.s0.e0     DDI-DrugBank.d7.s0.e1
# 24     24  False     DDI-DrugBank.d7.s1.e0     DDI-DrugBank.d7.s1.e1
# 25     25   True     DDI-DrugBank.d7.s2.e0     DDI-DrugBank.d7.s2.e1
# 26     26   True   DDI-DrugBank.d172.s6.e0   DDI-DrugBank.d172.s6.e1
# 27     27   True   DDI-DrugBank.d172.s6.e0   DDI-DrugBank.d172.s6.e2
# 28     28  False   DDI-DrugBank.d172.s6.e1   DDI-DrugBank.d172.s6.e2
# 29     29  False   DDI-DrugBank.d172.s7.e0   DDI-DrugBank.d172.s7.e1
# ..    ...    ...                       ...                       ...
# 70     70  False  DDI-DrugBank.d172.s14.e0  DDI-DrugBank.d172.s14.e2
# 71     71  False  DDI-DrugBank.d172.s14.e1  DDI-DrugBank.d172.s14.e2
# 72     72  False  DDI-DrugBank.d172.s15.e0  DDI-DrugBank.d172.s15.e1
# 73     73  False  DDI-DrugBank.d172.s16.e0  DDI-DrugBank.d172.s16.e1
# 74     74  False  DDI-DrugBank.d172.s16.e0  DDI-DrugBank.d172.s16.e2
# 75     75   True  DDI-DrugBank.d172.s16.e1  DDI-DrugBank.d172.s16.e2
# 76     76   True  DDI-DrugBank.d172.s17.e0  DDI-DrugBank.d172.s17.e1
# 77     77   True  DDI-DrugBank.d172.s18.e0  DDI-DrugBank.d172.s18.e1
# 78     78  False  DDI-DrugBank.d172.s19.e0  DDI-DrugBank.d172.s19.e1
# 79     79  False  DDI-DrugBank.d172.s19.e0  DDI-DrugBank.d172.s19.e2
# 80     80  False  DDI-DrugBank.d172.s19.e0  DDI-DrugBank.d172.s19.e3
# 81     81  False  DDI-DrugBank.d172.s19.e0  DDI-DrugBank.d172.s19.e4
# 82     82  False  DDI-DrugBank.d172.s19.e1  DDI-DrugBank.d172.s19.e2
# 83     83  False  DDI-DrugBank.d172.s19.e1  DDI-DrugBank.d172.s19.e3
# 84     84  False  DDI-DrugBank.d172.s19.e1  DDI-DrugBank.d172.s19.e4
# 85     85   True  DDI-DrugBank.d172.s19.e2  DDI-DrugBank.d172.s19.e3
# 86     86  False  DDI-DrugBank.d172.s19.e2  DDI-DrugBank.d172.s19.e4
# 87     87  False  DDI-DrugBank.d172.s19.e3  DDI-DrugBank.d172.s19.e4
# 88     88   True  DDI-DrugBank.d172.s20.e0  DDI-DrugBank.d172.s20.e1
# 89     89  False  DDI-DrugBank.d172.s21.e0  DDI-DrugBank.d172.s21.e1
# 90     90  False  DDI-DrugBank.d172.s21.e0  DDI-DrugBank.d172.s21.e2
# 91     91  False  DDI-DrugBank.d172.s21.e0  DDI-DrugBank.d172.s21.e3
# 92     92  False  DDI-DrugBank.d172.s21.e1  DDI-DrugBank.d172.s21.e2
# 93     93  False  DDI-DrugBank.d172.s21.e1  DDI-DrugBank.d172.s21.e3
# 94     94  False  DDI-DrugBank.d172.s21.e2  DDI-DrugBank.d172.s21.e3
# 95     95  False  DDI-DrugBank.d172.s22.e0  DDI-DrugBank.d172.s22.e1
# 96     96  False  DDI-DrugBank.d172.s22.e0  DDI-DrugBank.d172.s22.e2
# 97     97  False  DDI-DrugBank.d172.s22.e0  DDI-DrugBank.d172.s22.e3
# 98     98  False  DDI-DrugBank.d172.s22.e1  DDI-DrugBank.d172.s22.e2
# 99     99  False  DDI-DrugBank.d172.s22.e1  DDI-DrugBank.d172.s22.e3
#
#                sentenceID       type
# 0    DDI-DrugBank.d157.s0       null
# 1    DDI-DrugBank.d157.s0       null
# 2    DDI-DrugBank.d157.s0       null
# 3    DDI-DrugBank.d157.s1  mechanism
# 4    DDI-DrugBank.d157.s1       null
# 5    DDI-DrugBank.d157.s1       null
# 6    DDI-DrugBank.d110.s0       null
# 7    DDI-DrugBank.d110.s0       null
# 8    DDI-DrugBank.d110.s0       null
# 9    DDI-DrugBank.d110.s0     effect
# 10   DDI-DrugBank.d110.s0     effect
# 11   DDI-DrugBank.d110.s0       null
# 12   DDI-DrugBank.d110.s0     effect
# 13   DDI-DrugBank.d110.s0     effect
# 14   DDI-DrugBank.d110.s0     effect
# 15   DDI-DrugBank.d110.s0     effect
# 16   DDI-DrugBank.d110.s0     effect
# 17   DDI-DrugBank.d110.s0     effect
# 18   DDI-DrugBank.d110.s0       null
# 19   DDI-DrugBank.d110.s0       null
# 20   DDI-DrugBank.d110.s0       null
# 21   DDI-DrugBank.d110.s3     effect
# 22   DDI-DrugBank.d110.s5     advise
# 23     DDI-DrugBank.d7.s0  mechanism
# 24     DDI-DrugBank.d7.s1       null
# 25     DDI-DrugBank.d7.s2     effect
# 26   DDI-DrugBank.d172.s6        int
# 27   DDI-DrugBank.d172.s6        int
# 28   DDI-DrugBank.d172.s6       null
# 29   DDI-DrugBank.d172.s7       null
# ..                    ...        ...
# 70  DDI-DrugBank.d172.s14       null
# 71  DDI-DrugBank.d172.s14       null
# 72  DDI-DrugBank.d172.s15       null
# 73  DDI-DrugBank.d172.s16       null
# 74  DDI-DrugBank.d172.s16       null
# 75  DDI-DrugBank.d172.s16  mechanism
# 76  DDI-DrugBank.d172.s17  mechanism
# 77  DDI-DrugBank.d172.s18     advise
# 78  DDI-DrugBank.d172.s19       null
# 79  DDI-DrugBank.d172.s19       null
# 80  DDI-DrugBank.d172.s19       null
# 81  DDI-DrugBank.d172.s19       null
# 82  DDI-DrugBank.d172.s19       null
# 83  DDI-DrugBank.d172.s19       null
# 84  DDI-DrugBank.d172.s19       null
# 85  DDI-DrugBank.d172.s19  mechanism
# 86  DDI-DrugBank.d172.s19       null
# 87  DDI-DrugBank.d172.s19       null
# 88  DDI-DrugBank.d172.s20     advise
# 89  DDI-DrugBank.d172.s21       null
# 90  DDI-DrugBank.d172.s21       null
# 91  DDI-DrugBank.d172.s21       null
# 92  DDI-DrugBank.d172.s21       null
# 93  DDI-DrugBank.d172.s21       null
# 94  DDI-DrugBank.d172.s21       null
# 95  DDI-DrugBank.d172.s22       null
# 96  DDI-DrugBank.d172.s22       null
# 97  DDI-DrugBank.d172.s22       null
# 98  DDI-DrugBank.d172.s22       null
# 99  DDI-DrugBank.d172.s22       null
#
# [100 rows x 6 columns]

# %%
sentences_train = [row['sentenceText'] for index, row in sentences_df_train.iterrows()]
sentenceIDs_train = [row['sentenceID'] for index, row in sentences_df_train.iterrows()]

#sentences_test = [row['sentenceText'] for index, row in sentences_df_test.iterrows()]
#sentences_IDs_test = [row['sentenceID'] for index, row in sentences_df_test.iterrows()]

# %%
for index, row in pairs_df_train.iterrows():
    #print(row)
    sentenceID = row['sentenceID']
    sentence = sentences_train[sentenceIDs_train.index(sentenceID)]
    entityID1 = row['entityID1']
    entityID2 = row['entityID2']
    #print(sentence)
    #print(entityID1, entityID2)

# %%
has_2_entities = lambda x: len(x) == 2
has_3_or_more_entities = lambda x: len(x) >= 3

feature_list = [has_2_entities, 
                 has_3_or_more_entities]

for index, row in sentences_df_train.iterrows():
    sentenceId = row['sentenceID']
    temp_df = pairs_df_train[pairs_df_train.sentenceID == sentenceId]
    print(temp_df.head())
    if temp_df.shape[0] > 1:
        print("ALERT: more pairs in a sentence")
        for _, pair in temp_df.iterrows():
            print(pair)
    
    for feature in feature_list:
        print(feature(temp_df))
    
    break
# Out:
#    index    ddi                entityID1                entityID2  \
# 0      0   True  DDI-DrugBank.d281.s0.e0  DDI-DrugBank.d281.s0.e1
# 1      1  False  DDI-DrugBank.d281.s0.e0  DDI-DrugBank.d281.s0.e2
# 2      2  False  DDI-DrugBank.d281.s0.e1  DDI-DrugBank.d281.s0.e2
#
#              sentenceID       type
# 0  DDI-DrugBank.d281.s0  mechanism
# 1  DDI-DrugBank.d281.s0       null
# 2  DDI-DrugBank.d281.s0       null
# ALERT: more pairs in a sentence
# index                               0
# ddi                              True
# entityID1     DDI-DrugBank.d281.s0.e0
# entityID2     DDI-DrugBank.d281.s0.e1
# sentenceID       DDI-DrugBank.d281.s0
# type                        mechanism
# Name: 0, dtype: object
# index                               1
# ddi                             False
# entityID1     DDI-DrugBank.d281.s0.e0
# entityID2     DDI-DrugBank.d281.s0.e2
# sentenceID       DDI-DrugBank.d281.s0
# type                             null
# Name: 1, dtype: object
# index                               2
# ddi                             False
# entityID1     DDI-DrugBank.d281.s0.e1
# entityID2     DDI-DrugBank.d281.s0.e2
# sentenceID       DDI-DrugBank.d281.s0
# type                             null
# Name: 2, dtype: object
# False
# True

# %%
def token_distance(sentence, entity1, entity2):
    e1 = sentence.index(entity1)
    e2 = sentence[e1+1:].index(entity2) + (e1 + 1)
    return abs(e2 - e1) - 1

# %%
token_distance(["Hey", "medic", "is", "not", "like", "anything", "unusual", "penicilin"], "medic", "penicilin")
# Out:
# 5

# %%
triggers = {}
with open(os.path.join(ROOT_DIR, 'triggers.txt'), 'r') as triggerfile:
    for line in triggerfile:
        interaction_type, trigger = line.split()
        triggers[trigger] = interaction_type
#print(triggers)

# %%
def check_for(all_words, words_list):
    for word in all_words:
        if word.lower() in words_list:
            return 1
    return 0

# %%
def are_there_triggers(sentence, entity1, entity2):
    e1 = sentence.index(entity1.split()[0])
    e2 = sentence[e1+1:].index(entity2.split()[-1]) + (e1 + 1)
    between = sentence[e1+1:e2]
    for word in sentence[:e2]:
        if word in triggers.keys():
            return 1
    return 0

# %%
are_there_triggers(["Hey", "medic", "is", "not", "mustn't", "anything", "unusual", "penicilin"], "medic", "penicilin")
# Out:
# 1

# %%
conjunctions = ["and", "or", "even", "but", "for", "nor", "so", "yet"]

def are_there_conjunctions(sentence, entity1, entity2):
    e1 = sentence.index(entity1.split()[0])
    e2 = sentence[e1+1:].index(entity2.split()[-1]) + (e1 + 1)
    between = sentence[e1+1:e2]
    return check_for(between, conjunctions)

# %%
are_there_conjunctions(["Hey", "medic", "is", "not", "mustn't", "and", "anything", "unusual", "penicilin"], "medic", "penicilin")
# Out:
# 1

# %%
punctuation = [",", ";", ":", "/", "\\", "?", "!", "(", ")"]
def is_there_punctuation(sentence, entity1, entity2):
    e1 = sentence.index(entity1.split()[0])
    e2 = sentence[e1+1:].index(entity2.split()[-1]) + (e1 + 1)
    between = sentence[e1+1:e2]
    return check_for(between, punctuation)

# %%
is_there_punctuation(["Hey", "medic", "is", "not",",", "mustn't", "and", "anything", "unusual", "penicilin"], "medic", "penicilin")
# Out:
# 1

# %%
negations = ["no", "not", "none", "nobody", "nothing", "neither", "nowhere", "never", "n\'t"]

# %%
def is_there_negation(sentence, entity1, entity2):
    e1 = sentence.index(entity1.split()[0])
    e2 = sentence[e1+1:].index(entity2.split()[-1]) + (e1 + 1)
    upto2nd = sentence #[:e2]
    return check_for(upto2nd, negations)

# %%
is_there_negation(["Hey", "medic", "is", ",", "Not",  "mustn't", "and", "anything", "unusual", "penicilin"], "medic", "penicilin")
# Out:
# 1

# %%
m = 5 #nmb of features

def build_feature_matrix(df, entities_df):
    X = np.zeros([df.shape[0], m])
    for index, row in df.iterrows():
        sentenceID = row['sentenceID']
        entityID1 = row['entityID1']
        entityID2 = row['entityID2']
        entity1 = entities_df_train.loc[entities_df.entityID == entityID1]['name'].values[0]
        entity2 = entities_df_train.loc[entities_df.entityID == entityID2]['name'].values[0]
        sentence = sentences_train[sentenceIDs_train.index(sentenceID)]   
        #print(sentence, "----", entity2, "\n\n")
        #print(entity1, "|", entity2, "\n", sentence)
        vector = [is_there_negation(sentence, entity1, entity2), 
                are_there_triggers(sentence, entity1, entity2),
                token_distance(sentence, entity1, entity2),
                is_there_punctuation(sentence, entity1, entity2),
                are_there_conjunctions(sentence, entity1, entity2)]
                # + add embeddings if wanted
        vector = np.array(vector).reshape(1, -1)
        #print(vector.shape, X_tr.shape)
        X[index,:] = vector
    return X

X_tr = build_feature_matrix(pairs_df_train, entities_df_train)
print(X_tr.shape)
# Out:
# (27663, 5)

# %%
print(X_tr.shape, Y_tr.shape)
# Out:
# (27663, 5) (27663, 1)

# %% [markdown]
# ### svm grid search

# %%
model = SVC(kernel='rbf', 
                C=1.0,
                class_weight=None,
                gamma='auto',
                #penalty='l2',
                #loss='squared_hinge',
                tol=0.001, random_state=None)

# %%
param_grid = {'kernel': ['linear', 'rbf'], 'C': [0.01, 0.1, 1, 10] }

gs_clf = GridSearchCV(model, param_grid, cv=5, verbose=50)
gs_clf = gs_clf.fit(X_tr, Y_tr)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] kernel=linear, C=0.01 ...........................................
# [CV] .................. kernel=linear, C=0.01, score=0.855413 -   8.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    8.0s remaining:    0.0s
# [CV] kernel=linear, C=0.01 ...........................................
# [CV] .................. kernel=linear, C=0.01, score=0.855413 -   9.7s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   17.7s remaining:    0.0s
# [CV] kernel=linear, C=0.01 ...........................................
# [CV] .................. kernel=linear, C=0.01, score=0.855413 -   9.5s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   27.2s remaining:    0.0s
# [CV] kernel=linear, C=0.01 ...........................................
# [CV] .................. kernel=linear, C=0.01, score=0.855413 -  10.3s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   37.5s remaining:    0.0s
# [CV] kernel=linear, C=0.01 ...........................................
# [CV] .................. kernel=linear, C=0.01, score=0.855541 -  10.9s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   48.4s remaining:    0.0s
# [CV] kernel=rbf, C=0.01 ..............................................
# [CV] ..................... kernel=rbf, C=0.01, score=0.855413 -   5.8s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   54.3s remaining:    0.0s
# [CV] kernel=rbf, C=0.01 ..............................................
# [CV] ..................... kernel=rbf, C=0.01, score=0.855413 -   5.8s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  1.0min remaining:    0.0s
# [CV] kernel=rbf, C=0.01 ..............................................
# [CV] ..................... kernel=rbf, C=0.01, score=0.855413 -   5.4s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  1.1min remaining:    0.0s
# [CV] kernel=rbf, C=0.01 ..............................................
# [CV] ..................... kernel=rbf, C=0.01, score=0.855413 -   5.3s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  1.2min remaining:    0.0s
# [CV] kernel=rbf, C=0.01 ..............................................
# [CV] ..................... kernel=rbf, C=0.01, score=0.855541 -   5.4s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  1.3min remaining:    0.0s
# [CV] kernel=linear, C=0.1 ............................................
# [CV] ................... kernel=linear, C=0.1, score=0.855413 -  48.2s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:  2.1min remaining:    0.0s
# [CV] kernel=linear, C=0.1 ............................................
# [CV] ................... kernel=linear, C=0.1, score=0.855413 - 1.1min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  3.2min remaining:    0.0s
# [CV] kernel=linear, C=0.1 ............................................
# [CV] ................... kernel=linear, C=0.1, score=0.855413 - 1.2min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:  4.4min remaining:    0.0s
# [CV] kernel=linear, C=0.1 ............................................
# [CV] ................... kernel=linear, C=0.1, score=0.855413 - 1.2min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:  5.5min remaining:    0.0s
# [CV] kernel=linear, C=0.1 ............................................
# [CV] ................... kernel=linear, C=0.1, score=0.855541 - 1.2min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:  6.7min remaining:    0.0s
# [CV] kernel=rbf, C=0.1 ...............................................
# [CV] ...................... kernel=rbf, C=0.1, score=0.855413 -   6.1s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:  6.8min remaining:    0.0s
# [CV] kernel=rbf, C=0.1 ...............................................
# [CV] ...................... kernel=rbf, C=0.1, score=0.855413 -   5.8s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:  6.9min remaining:    0.0s
# [CV] kernel=rbf, C=0.1 ...............................................
# [CV] ...................... kernel=rbf, C=0.1, score=0.855413 -   6.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:  7.0min remaining:    0.0s
# [CV] kernel=rbf, C=0.1 ...............................................
# [CV] ...................... kernel=rbf, C=0.1, score=0.855413 -   5.8s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:  7.1min remaining:    0.0s
# [CV] kernel=rbf, C=0.1 ...............................................
# [CV] ...................... kernel=rbf, C=0.1, score=0.855541 -   6.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:  7.2min remaining:    0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ..................... kernel=linear, C=1, score=0.855413 - 9.1min
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed: 16.2min remaining:    0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ..................... kernel=linear, C=1, score=0.855413 -14.8min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 31.1min remaining:    0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ..................... kernel=linear, C=1, score=0.855413 - 9.4min
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed: 40.4min remaining:    0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ..................... kernel=linear, C=1, score=0.855413 - 8.5min
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed: 48.9min remaining:    0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ..................... kernel=linear, C=1, score=0.855541 - 6.5min
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 55.4min remaining:    0.0s
# [CV] kernel=rbf, C=1 .................................................
# [CV] ........................ kernel=rbf, C=1, score=0.852702 -   7.1s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed: 55.5min remaining:    0.0s
# [CV] kernel=rbf, C=1 .................................................
# [CV] ........................ kernel=rbf, C=1, score=0.855413 -   7.9s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 55.7min remaining:    0.0s
# [CV] kernel=rbf, C=1 .................................................
# [CV] ........................ kernel=rbf, C=1, score=0.855955 -   7.3s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed: 55.8min remaining:    0.0s
# [CV] kernel=rbf, C=1 .................................................
# [CV] ........................ kernel=rbf, C=1, score=0.855232 -   7.1s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed: 55.9min remaining:    0.0s
# [CV] kernel=rbf, C=1 .................................................
# [CV] ........................ kernel=rbf, C=1, score=0.855180 -   7.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 56.0min remaining:    0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] .................... kernel=linear, C=10, score=0.855413 -68.6min
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed: 124.7min remaining:    0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] ................... kernel=linear, C=10, score=0.855413 -107.5min
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed: 232.2min remaining:    0.0s
# [CV] kernel=linear, C=10 .............................................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-c9545e2c4e6f> in <module>()
#       2
#       3 gs_clf = GridSearchCV(model, param_grid, cv=5, verbose=50)
# ----> 4 gs_clf = gs_clf.fit(X_tr, Y_tr)
#
# /usr/local/lib/python3.5/dist-packages/sklearn/grid_search.py in fit(self, X, y)
#     836
#     837         """
# --> 838         return self._fit(X, y, ParameterGrid(self.param_grid))
#     839
#     840
#
# /usr/local/lib/python3.5/dist-packages/sklearn/grid_search.py in _fit(self, X, y, parameter_iterable)
#     572                                     self.fit_params, return_parameters=True,
#     573                                     error_score=self.error_score)
# --> 574                 for parameters in parameter_iterable
#     575                 for train, test in cv)
#     576
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, error_score)
#    1673             estimator.fit(X_train, **fit_params)
#    1674         else:
# -> 1675             estimator.fit(X_train, y_train, **fit_params)
#    1676
#    1677     except Exception as e:
#
# /usr/local/lib/python3.5/dist-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     185
#     186         seed = rnd.randint(np.iinfo('i').max)
# --> 187         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     188         # see comment on the other call to np.iinfo in this file
#     189
#
# /usr/local/lib/python3.5/dist-packages/sklearn/svm/base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     252                 cache_size=self.cache_size, coef0=self.coef0,
#     253                 gamma=self._gamma, epsilon=self.epsilon,
# --> 254                 max_iter=self.max_iter, random_seed=random_seed)
#     255
#     256         self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
model.fit(X_tr, Y_tr)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-2f5ef787226b> in <module>()
# ----> 1 model.fit(X_tr, Y_tr)
#
# /usr/local/lib/python3.5/dist-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     185
#     186         seed = rnd.randint(np.iinfo('i').max)
# --> 187         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     188         # see comment on the other call to np.iinfo in this file
#     189
#
# /usr/local/lib/python3.5/dist-packages/sklearn/svm/base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     252                 cache_size=self.cache_size, coef0=self.coef0,
#     253                 gamma=self._gamma, epsilon=self.epsilon,
# --> 254                 max_iter=self.max_iter, random_seed=random_seed)
#     255
#     256         self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
Y_predicted = model.predict(X_tr)

# %%
sum(Y_predicted == Y_train)/len(Y_predicted)
# Out:
# array([0.85543867, 0.85543867, 0.85543867, ..., 0.85543867, 0.85543867,
#        0.85543867])
