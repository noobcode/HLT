# %%
# Gensim
import gensim
from gensim.models import Word2Vec

import pandas as pd
import numpy as np

from analize_text import get_sentenceID
from paths import *

# nltk
import nltk
from nltk import word_tokenize

from multiprocessing import cpu_count
from sklearn.pipeline import FeatureUnion, Pipeline

# %%
sentences_df = pd.read_csv(SENTENCE_PATH)
entities_df = pd.read_csv(ENTITY_PATH)
entities_df.head()
# Out:
#                   entityID        name position   type
# 0  DDI-DrugBank.d157.s0.e0  cimetidine    34-43   drug
# 1  DDI-DrugBank.d157.s0.e1    warfarin    49-56   drug
# 2  DDI-DrugBank.d157.s0.e2      Femara   97-102  brand
# 3  DDI-DrugBank.d157.s1.e0      Femara    48-53  brand
# 4  DDI-DrugBank.d157.s1.e1   tamoxifen    59-67   drug

# %%
entities = entities_df['entityID']
sentences = [sentences_df.loc[sentences_df.sentenceID == get_sentenceID(entity)]['sentenceText'].values[0] for entity in entities]    

sentences
# Out:
# ['Clinical interaction studies with cimetidine and warfarin indicated that the coadministration of Femara with these drugs does not result in clinically- significant drug interactions.',
#  'Clinical interaction studies with cimetidine and warfarin indicated that the coadministration of Femara with these drugs does not result in clinically- significant drug interactions.',
#  'Clinical interaction studies with cimetidine and warfarin indicated that the coadministration of Femara with these drugs does not result in clinically- significant drug interactions.',
#  '(See CLINICAL PHARMACOLOGY) Coadministration of Femara and tamoxifen 20 mg daily resulted in a reduction of letrozole plasma levels by 38% on average.',
#  '(See CLINICAL PHARMACOLOGY) Coadministration of Femara and tamoxifen 20 mg daily resulted in a reduction of letrozole plasma levels by 38% on average.',
# ...

# %%
for s in sentences:
    if isinstance(s, float):
        print True

# %%
sentences = [word_tokenize(sentence) for sentence in sentences]
sentences[:2]
# Out:
# [['Clinical',
#   'interaction',
#   'studies',
#   'with',
#   'cimetidine',
#   'and',
#   'warfarin',
#   'indicated',
#   'that',
#   'the',
#   'coadministration',
#   'of',
#   'Femara',
#   'with',
#   'these',
#   'drugs',
#   'does',
#   'not',
#   'result',
#   'in',
#   'clinically-',
#   'significant',
#   'drug',
#   'interactions',
#   '.'],
#  ['Clinical',
#   'interaction',
#   'studies',
#   'with',
#   'cimetidine',
#   'and',
#   'warfarin',
#   'indicated',
#   'that',
#   'the',
#   'coadministration',
#   'of',
#   'Femara',
#   'with',
#   'these',
#   'drugs',
#   'does',
#   'not',
#   'result',
#   'in',
#   'clinically-',
#   'significant',
#   'drug',
#   'interactions',
#   '.']]

# %%
model = Word2Vec(sentences, size=20, window=5, min_count=1, workers=cpu_count(), compute_loss=True)
model.train(sentences, total_examples=len(sentences), epochs=10)
print (model.get_latest_training_loss())
# Out:
# 0.0

# %%
model["interaction"]
# Out:
# /home/carlo/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-4.1796937 , -3.03945446, -2.75279236, -0.63430703, -3.90423274,
#         2.48067498, -0.17577474,  3.04136014,  2.74575138, -7.29024029,
#         4.73872662,  1.67633593, -2.61897159,  1.56507266, -2.45561337,
#         1.28405118,  3.4313817 , -3.79955792,  0.86090815, -5.02433777], dtype=float32)

# %%
help(Word2Vec)
# Out:
# Help on class Word2Vec in module gensim.models.word2vec:
#
# class Word2Vec(gensim.models.base_any2vec.BaseWordEmbeddingsModel)
#  |  Class for training, using and evaluating neural networks described in https://code.google.com/p/word2vec/
#  |
#  |  If you're finished training a model (=no more updates, only querying)
#  |  then switch to the :mod:`gensim.models.KeyedVectors` instance in wv
#  |
#  |  The model can be stored/loaded via its :meth:`~gensim.models.word2vec.Word2Vec.save()` and
#  |  :meth:`~gensim.models.word2vec.Word2Vec.load()` methods, or stored/loaded in a format
#  |  compatible with the original word2vec implementation via `wv.save_word2vec_format()`
#  |  and `Word2VecKeyedVectors.load_word2vec_format()`.
#  |
#  |  Method resolution order:
#  |      Word2Vec
#  |      gensim.models.base_any2vec.BaseWordEmbeddingsModel
#  |      gensim.models.base_any2vec.BaseAny2VecModel
#  |      gensim.utils.SaveLoad
#  |      __builtin__.object
#  |
# ...

# %%
model.save("../word_vectors")

# %%
model = Word2Vec.load('../word_vectors')

# %%
#new_sentence = ['the', 'cat', 'eats', 'fish']
#model.train(sentences, total_examples=len(sentences), epochs=10)
#print (model.get_latest_training_loss())
#print model['interaction'], model['cat']

# %%
features = FeatureUnion(
('words-counter', WordsCounter),
)
